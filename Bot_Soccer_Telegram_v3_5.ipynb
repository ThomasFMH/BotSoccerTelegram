# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasFMH/BotSoccerTelegram/blob/main/Bot_Soccer_Telegram_v3_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar as Bibliotecas

# %%
pip install python-time
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 2.5 MB/s eta 0:00:00
# ...
#   Created wheel for python-time: filename=python_time-0.3.0-py3-none-any.whl size=2777 sha256=f11a7381ca371a0eac959739f8821ac334d5f4173decabbc186ee4c19f6a9b92
#   Stored in directory: /root/.cache/pip/wheels/1d/34/24/52a1f375e8d0eb2301fef542991035bd22b5fc645170a3ad8a
# Successfully built python-time
# ...

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install jsonlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for jsonlib
#   Running setup.py clean for jsonlib
# Failed to build jsonlib
# ...
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for jsonlib did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Running setup.py install for jsonlib ... error
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> jsonlib
#
# ...

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import time
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

# %% [markdown]
# # Token Telegram

# %%
token = '6060034825:AAFVjl7CiklcHi3Y5XgXe0j3ocPdXRM6Hgg'
chat_id = '-1001747647086'

# %% [markdown]
# # CORPO DO BOT

# %%
while True: 
          
    url = "https://api.sportsanalytics.com.br/api/v1/fixtures-svc/fixtures/livescores?include=weatherReport,additionalInfo,league,stats,pressureStats,probabilities"

    headers = {     
    "cookie": "route=f69973370a0dd0883a57c7b955dfc742; SRVGROUP=common",
    "authority": "api.sportsanalytics.com.br",
    "accept": "application/json, text/plain, */*",
    "accept-language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "origin": "https://playscores.com",
    "referer": "https://playscores.com/",
    "sec-ch-ua": "^\^Google",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "^\^Windows^^",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "cross-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"
    }

    time.sleep(15)
            
    response = requests.request("GET", url, headers=headers)
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    dic_response = response.json()
    num_games_live = dic_response['total']
    #print('Jogos em Live =', num_games_live)
    
    for game in dic_response['data']:
        try:
            fixtureId = game['fixtureId']
            date = game['date']
            # Team
            awayTeam = game['awayTeam']['name']
            homeTeam = game['homeTeam']['name']       
            league = game['league']['name']
            log_game = ('FIXID', fixtureId, 'League', league, '=>', homeTeam, 'VS', awayTeam)
            #print(log_game)
            # currentTime
            minute = game['currentTime']['minute']
            second = game['currentTime']['second']
            # scores
            homeTeamScore = game['scores']['homeTeamScore']
            awayTeamScore = game['scores']['awayTeamScore']
            # corners
            corners_home = game['stats']['corners']['home']
            corners_away = game['stats']['corners']['away']
            # dangerousAttacks
            dangerousAttacks_home = game['stats']['dangerousAttacks']['home']
            dangerousAttacks_away = game['stats']['dangerousAttacks']['away']
            # shotsOffgoal
            shotsOffgoal_home = game['stats']['shotsOffgoal']['home']
            shotsOffgoal_away = game['stats']['shotsOffgoal']['away']
            # shotsOngoal
            shotsOngoal_home = game['stats']['shotsOngoal']['home']
            shotsOngoal_away = game['stats']['shotsOngoal']['away']
            # yellowredcards
            yellowredcards_home = game['stats']['yellowredcards']['home']
            yellowredcards_away = game['stats']['yellowredcards']['away']
            # appm1
            appm1_home = game['pressureStats']['appm1']['home']
            appm1_away = game['pressureStats']['appm1']['away']
            # appm2
            appm2_home = game['pressureStats']['appm2']['home']
            appm2_away = game['pressureStats']['appm2']['away']
            # exg
            exg_home = game['pressureStats']['exg']['home']
            exg_away = game['pressureStats']['exg']['away']
            # mh1
            mh1_home = game['pressureStats']['mh1']['home']
            mh1_away = game['pressureStats']['mh1']['away']
            # mh2
            mh2_home = game['pressureStats']['mh2']['home']
            mh2_away = game['pressureStats']['mh2']['away']
            # mh3
            mh3_home = game['pressureStats']['appm1']['home']
            mh3_away = game['pressureStats']['appm1']['away']
            # weather
            temperature = game['weatherReport']['temperature']
            clouds = game['weatherReport']['clouds']
            humidity = game['weatherReport']['humidity']
            wind = game['weatherReport']['wind']

            time.sleep(1)
        except:
            corners_home = [None]
            corners_away = [None]
            dangerousAttacks_home = [None]
            dangerousAttacks_away = [None]
            shotsOffgoal_home = [None]
            shotsOffgoal_away = [None]
            shotsOngoal_home = [None]
            shotsOngoal_away = [None]
            yellowredcards_home = [None]
            yellowredcards_away = [None]
            appm1_home = [None]
            appm1_away = [None]
            appm2_home = [None]
            appm2_away = [None]
            exg_home = [None]
            exg_away = [None]
            mh1_home = [None]
            mh1_away = [None]
            mh2_home = [None]
            mh2_away = [None]
            mh3_home = [None]
            mh3_away = [None]
            temperature = [None]
            clouds = [None]
            humidity = [None]
            wind = [None]
            continue

        def send_telegram_message(token, chat_id, homeTeam, awayTeam, league, minute, temperature, clouds, humidity, wind, homeTeamScore, awayTeamScore, exg_home, exg_away, dangerousAttacks_home, dangerousAttacks_away, shotsOngoal_home, shotsOngoal_away, shotsOffgoal_home, shotsOffgoal_away, corners_home, corners_away):          
            corners_total = corners_home + corners_away + 0.5
            text = '''🔔ESTRATÉGIA - ESCANTEIO ASIÁTICOS 🚩:\n\n🆚 {} VS {}\n🏆 {}\n⏰ {} minutos\n\nInformações do clima da partida:\n🌡️ {}°C / ☁️ {} / 💧 {} / 💨 {}\n\nEstatísticas (Casa - Fora)\n📈 Placar: {} - {}\n🌡 EXG : {} - {}\n🔥 Ataques Perigosos: {} - {}\n🎯 Chutes ao gol: {} - {}\n💥 Chutes fora do gol: {} - {}\n⛳️ Escanteios: {} - {}\n\n✅ Entrada Tip:\n▪️Mais de {} Escanteios\n▪️ODD's 2 ou menor\n\n⚠️ Realize gerenciamento de banca adequado para cada entrada.\n'''.format(homeTeam, awayTeam, league, minute, temperature, clouds, humidity, wind, homeTeamScore, awayTeamScore, exg_home, exg_away, dangerousAttacks_home, dangerousAttacks_away, shotsOngoal_home, shotsOngoal_away, shotsOffgoal_home, shotsOffgoal_away, corners_home, corners_away,corners_total)
            url_base = f'https://api.telegram.org/bot{token}/sendMessage?chat_id={chat_id}&text={text}'
            results = requests.get(url_base)
            print(text)

        def process_strategy1_game(minute, homeTeamScore, awayTeamScore):
            if minute >= 80 and minute <= 80:
                if awayTeamScore - homeTeamScore == 1 or awayTeamScore == homeTeamScore:
                    find_strategy_log = (minute, '|', homeTeam, 'VS', awayTeam, '|', 'JOGO STRATEGIA- 1 ENCONTRADO!')
                    print(find_strategy_log)
                    send_telegram_message(token, chat_id, homeTeam, awayTeam, league, minute, temperature, clouds, humidity, wind, homeTeamScore, awayTeamScore, exg_home, exg_away, dangerousAttacks_home, dangerousAttacks_away, shotsOngoal_home, shotsOngoal_away, shotsOffgoal_home, shotsOffgoal_away, corners_home, corners_away)                                
                    time.sleep(45)
        #process_strategy1_game(minute, homeTeamScore, awayTeamScore)

        def process_strategy2_game(minute, appm1_home, appm1_away, exg_home, exg_away, homeTeamScore, awayTeamScore):
            if minute >= 35 and minute <= 35 or minute >= 83 and minute <= 83:
                if appm1_home + appm1_away / 2 >= 1 and exg_home + exg_away / 2 >= 1.5:
                    if awayTeamScore - homeTeamScore == 1 or awayTeamScore == homeTeamScore:
                        find_strategy_log = (minute, '|', homeTeam, 'VS', awayTeam, '|', 'JOGO STRATEGIA - 2 ENCONTRADO!') #https://www.youtube.com/watch?v=U6Yc433sY7Q
                        print(find_strategy_log)
                        send_telegram_message(token, chat_id, homeTeam, awayTeam, league, minute, temperature, clouds, humidity, wind, homeTeamScore, awayTeamScore, exg_home, exg_away, dangerousAttacks_home, dangerousAttacks_away, shotsOngoal_home, shotsOngoal_away, shotsOffgoal_home, shotsOffgoal_away, corners_home, corners_away)                                
                        time.sleep(45)
        process_strategy2_game(minute, appm1_home, appm1_away, exg_home, exg_away, homeTeamScore, awayTeamScore)
# Out:
# (83, '|', 'Al Ahli', 'VS', 'Al-Hidd', '|', 'JOGO STRATEGIA - 2 ENCONTRADO!')
# 🔔ESTRATÉGIA - ESCANTEIO ASIÁTICOS 🚩:
#
# 🆚 Al Ahli VS Al-Hidd
# 🏆 Bahrain - Premier League
# ⏰ 83 minutos
#
# Informações do clima da partida:
# 🌡️ 16.3°C / ☁️ 0% / 💧 63% / 💨 18.41 m/s
#
# Estatísticas (Casa - Fora)
# 📈 Placar: 1 - 1
# 🌡 EXG : 1.35 - 1.85
# 🔥 Ataques Perigosos: 60 - 59
# 🎯 Chutes ao gol: 1 - 2
# 💥 Chutes fora do gol: 0 - 0
# ⛳️ Escanteios: 3 - 2
#
# ✅ Entrada Tip:
# ▪️Mais de 5.5 Escanteios
# ▪️ODD's 2 ou menor
#
# ⚠️ Realize gerenciamento de banca adequado para cada entrada.
#
# (83, '|', 'FC Serpa', 'VS', 'Praiense', '|', 'JOGO STRATEGIA - 2 ENCONTRADO!')
# 🔔ESTRATÉGIA - ESCANTEIO ASIÁTICOS 🚩:
#
# 🆚 FC Serpa VS Praiense
# 🏆 Portugal - 2. Division: Group D
# ⏰ 83 minutos
#
# Informações do clima da partida:
# 🌡️ 19.4°C / ☁️ 85% / 💧 57% / 💨 4.27 m/s
#
# Estatísticas (Casa - Fora)
# 📈 Placar: 1 - 2
# 🌡 EXG : 1.25 - 1.6
# 🔥 Ataques Perigosos: 59 - 56
# 🎯 Chutes ao gol: 2 - 7
# ...

# %% [markdown]
# # Visualizar dados gerados
#
# dic_response = response.json()['data']
#
# dados = pd.DataFrame.from_dict(dic_response)
#
# dados
#
# dados.to_excel("dados_playscores.xlsx", encoding='utf-8', index=False)
#
# dados.info()
